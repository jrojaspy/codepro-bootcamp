# %%
nombre = "Juan"
edad = 44
ciudad = "Capiata"

print(nombre, edad, ciudad)
# Out:
# Juan 44 Capiata

# %%
producto1 = "papas fritas"
costo_producto1 = 15000
producto2 = "coca cola"
costo_producto2 = 14000
capital = 50000
dolar = 6700

costo_total = costo_producto1 + costo_producto2
print("El costo total es de: ", costo_total)

vuelto = capital - costo_total
print("El vuelto es de: ", vuelto)

vuelto_dolar = round(vuelto / dolar, 2) # round para redondear a dos decimales
print("El vuelto en dolares es de: ", vuelto_dolar)
# Out:
# El costo total es de:  29000
# El vuelto es de:  21000
# El vuelto en dolares es de:  3.13

# %%
edad = 28
altura = 1.80
nombre = "Maggi"
feliz = True

# print(edad)
# print(altura)
# print(nombre)
# print(feliz)

print(edad, altura, nombre, feliz)
# Out:
# 28 1.8 Maggi True

# %%
# suma
cantidad_de_manzanas = 4
cantidad_de_naranjas = 8
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
print("la cantidad de frutas es de: ", cantidad_de_frutas)

# resta
frutas_vendidas = 10
frutas_restantes= cantidad_de_frutas - frutas_vendidas
print("la cantidad de frutas restantes: ", frutas_restantes)
# Out:
# la cantidad de frutas es de:  12
# la cantidad de frutas restantes:  2

# %%
# Frase famosa
frase_famosa = "hola mundo"
print(frase_famosa)

# Orden de ejecucion
fruta = "naranja"
print(fruta)

cantidad_de_frutas = 4
print(cantidad_de_frutas)

fruta = "banana"
print(fruta)
# Out:
# hola mundo
# naranja
# 4
# banana

# %%
print("hola mundo")
# Out:
# hola mundo

# %%
nombre = 'juan'
apellido = 'rojas'

print(nombre + ' ' + apellido)

print(f"Mi nombre es {nombre} {apellido}")
# Out:
# juan rojas
# Mi nombre es juan rojas

# %%
# Asignar el nombre y el apellido de tu compañera/o a las variables nombre y apellido. Luego, imprimir una frase, utilizando las variables.
# EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."

nombre = 'Aaron'
apellido = 'Barrios'

print(f"Hola {nombre} {apellido}. \nSoy Juan Rojas. Mucho gusto.")
# Out:
# Hola Aaron Barrios.
# Soy Juan Rojas. Mucho gusto.

# %%
nombre = input("Escribe tu nombre: ")
print(nombre)

# %%
producto = input("Que producto deseas?")
print(producto)

cantidad_de_producto = input("Cual es la cantidad de producto que deseas?")
print(cantidad_de_producto)

print(f"El usuario quiere {producto} y la cantidad es de {cantidad_de_producto}")

# %%
# Solicitar al usuario ingresar dos números y almacenarlos en dos variables. Luego, imprimir la suma de los dos números.

numero_1 = input("Ingrese el numero 1: ")
numero_2 = input("Ingrese el numero 2: ")

suma = numero_1 + numero_2

print(f"El resultado de la suma de los numeros es: ##### {suma} #####")

# %%
#### FUNCIONES ####

def preparar_sandwich():
    print("Preparar sandwich...")
    print("Ya esta el sandwich listo!")

preparar_sandwich()
# Out:
# Preparar sandwich...
# Ya esta el sandwich listo!

# %% [markdown]
# ## Funciones

# %%
# Crear una función de un proceso que se les ocurra que tenga varios pasos.
# Ejecutar la función 3 veces.

def preparar_cafe():
    print("####### PREPARACION DEL CAFE #######")
    print("1. Cargar el cafe a la cafetera.")
    print("2. Apretar el boton.")
    print("3. Pasar a la taza.")
    print("4. Endulzar.")
    print("5. Consumir.")
    print("####################################")

preparar_cafe()
preparar_cafe()
preparar_cafe()

# %%
ingrediente1 = "carne"                 # argumentos
ingrediente2 = "pollo"                  # argumentos
def preparar_sandwich(x, y):            # parametros
    print(f"El sandwich es de {x} y {y}")

preparar_sandwich(ingrediente1,ingrediente2)

# %%
# Escribir una funcion que nos pregunte las caracteristicas de un elemento a comprar e imprima el elemento con sus caracteristicas.

elemento = input("Ingrese el elemento a comprar: ")
color = input("Ingrese color: ")
marca = input("Ingrese el anho: ")
vencimiento = input("Ingrese el tipo de motor: ")

def comprar_elemento(elemento, color, marca, vencimiento):
    print(f"El {elemento} que desea comprar, es de color {}, anho {}, motor {})
          
comprar_elemento()

# %%
# Escribir una funcion que nos pregunte las caracteristicas de un elemento a comprar e imprima el elemento con sus caracteristicas.
def producto():
  elemento = input("Ingrese el elemento a comprar: ")
  color = input("Ingrese el color: ")
  marca = input("Ingrese la marca: ")
  tamanho = input("Ingrese el tamanho: ")
  return elemento, color, marca, tamanho

def comprar_elemento():
    producto()
    print(f"Desea comprar un/a {elemento}, de color {color}, marca {marca} y su tamanho {tamanho}")
          
comprar_elemento()

# %%
# Escribir una función que pregunte por las características de un producto a comprar
# (por ejemplo, tipo, tamaño, color) e imprima un resumen de ese producto con las características ingresadas.

producto = input("Escribe el nombre del producto: ")

def caracteristicas(producto):
    marca = input("Escribe la marca: ")
    color = input("Escribe el color: ")
    tamanho = input("Escribe el tamanho: ")
    print(f"El producto seleccionado es: {producto}, la marca es {marca}, el color es {color} y el tamanho {tamanho}")
