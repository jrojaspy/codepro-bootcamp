# %%
#Challenge 1 🤺 10m
#Escribir un programa que cree un diccionario vacío y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le pida al usuario. 

#Cada vez que se añada un nuevo dato debe imprimirse el contenido del diccionario.

datos_de_personas = {}

campos = ["nombre", "apellido", "edad", "correo"]

for dato in campos:
    datos_de_personas[dato] = input(f"Ingrese el valor del {dato}")

print(datos_de_personas)
# Out:
# {'nombre': 'Juan', 'apellido': 'Rojas', 'edad': '44', 'correo': 'jrojaspy@gmail.com'}

# %%
#Crear una tarjeta personal. El usuario (mediante input) puede elegir:

#Crear datos nuevos
#Modificar datos
#Eliminar datos



#opcion = input("La opcion elegida es: ")
#datos = {}

opcion = 0
contactos = {}
bucle = 1
clave = ""
valor = ""

while bucle == 1:

    print(""" Elija una opcion: 
            1. Crear dato nuevo
            2. Modificar datos
            3. Eliminar
            4. Imprimir contactos
            5. Salir""")
    
    opcion = int(input("Seleccione una opcion: "))


    if opcion == 1:
        clave = input("Que dato desea crear: ")
        valor = input("Que valor desea agregar: ")
        contactos[clave] = valor
        print("Datos actualizados")

    elif opcion == 2:
        clave = input("Que dato desea modificar: ")
        valor = input("Que valor desea agregar: ")
        contactos[clave] = valor
        print("Datos actualizados")

    elif opcion == 3:
        clave = print(input("Que dato desea eliminar: "))
        del contactos[clave]
        print("Datos actualizados")

    elif opcion == 4:
        for i, j in contactos.items():
            print(f"Nombre: {i} - Numero: {j}")

    else:
        bucle = 0
        print("Programa finalizado")

# %%
#Crear una agenda de contactos. El usuario puede elegir:

#Mostrar los contactos
#Crear contacto
#Modificar datos del contacto



#opcion = input("La opcion elegida es: ")
#datos = {}

opcion = 0
contactos = { : telefonos}
nombres = []
telefonos = [].nombre = nombre.nombre = nombre
        self.nivel = nivel
    
    def mostrar_datos(self):
        print(f"Nombre: {self.nombre}")
        print(f"Nivel: {self.nivel}")

class Guerrero(Personaje):
    def pelear():
        print("Soy {self.nombre} y voy a pelear en el Nivel {self.nivel}")

class Mago(Personaje):
    def pelear():
        self.nivel = nivel
    
    def mostrar_datos(self):
        print(f"Nombre: {self.nombre}")
        print(f"Nivel: {self.nivel}")

class Guerrero(Personaje):
    def pelear():
        print("Soy {self.nombre} y voy a pelear en el Nivel {self.nivel}")

class Mago(Personaje):
    def pelear():
bucle = 1
clave = ""
valor = ""

while bucle == 1:

    print(""" Elija una opcion: 
            1. Crear contacto nuevo
            2. Modificar datos
            3. Eliminar
            4. Imprimir contactos
            5. Salir""")
    
    opcion = int(input("Seleccione una opcion: "))


    if opcion == 1:
        contactos.append() =input("Que contacto desea agregar: ")
        telefonos.append() = input("Que telefono desea agregar: ")
        print("Datos actualizados")

    elif opcion == 2:
        clave = input("Que dato desea modificar: ")
        valor = input("Que valor desea agregar: ")
        print("Datos actualizados")

    elif opcion == 3:
        clave = print(input("Que dato desea eliminar: "))
        del contactos[clave]
        print("Datos actualizados")

    elif opcion == 4:
        for i, j in contactos.items():
            print(f"Nombre: {i} - Numero: {j}")

    else:
        bucle = 0
        print("Programa finalizado")

# %%
#Challenge 🤺  - 15 min
#Crear una clase animales que tenga atributo de clase y de instancia.

#Atributos de clase: especie.
#Atributos de instancia: nombre & color

#Luego, crear nuevos objetos a partir de las nuevas class. Imprimir el nombre y el color de los animales en una frase.
#Ejemplo: "Me llamo {nombre} y soy un ave de color {color}". 

class Animales:

    # Atributos de clase: Son compartidos por todos los objetos
    especie = "vertebrados"

    # Atributos de instancia: pertenencen a cada objeto
    def __init__(self, nombre, color):
        self.nombre = nombre
        self.color = color


anim1 = Animales("Gato", "Blanco")
anim2 = Animales("Elefante", "Gris")

print(f"Soy un {anim1.nombre} y mi color {anim1.color}")
print(f"Soy un {anim2.nombre} y mi color {anim2.color}")

# %%
#Challenge 2🤺 - 15 min
#Crear dos métodos para nuestro animal y ejecutar, debe ser algo específico de ese animal.

#Ejemplo: "Cuando hablo, digo X".
#Ejemplo: "Cuando me muevo, hago X".

class Animales:

    # Atributos de clase: Son compartidos por todos los objetos
    especie = "vertebrados"

    # Atributos de instancia: pertenencen a cada objeto o propiedades
    def __init__(self, nombre, color):
        self.nombre = nombre
        self.color = color

    # Definir metodos o acciones
    def sonido(self):
        veces = 2
        print("ronronea {self.veces} veces")
    
    def juego(self):
        distancia = 0
        print("salta a {self.distancia}")
        

anim1 = Animales("Gato", "Blanco")
anim2 = Animales("Elefante", "Gris")

print(f"Soy un {anim1.nombre} y mi color {anim1.color}")
print(f"Soy un {anim2.nombre} y mi color {anim2.color}")


anim1.sonido(2)
anim2.juego(2)

# %%
#Challenge 3🤺 - 15 min
#Definir una clase madre que herede a sus clases hijas dos atributos de instancia. Mostrar ambos atributos en pantalla desde los objetos de las clases hijas.

#Observación: Editar las clases hijas para que no se inicialicen.:

class Personaje:
    def __init__(self, nombre, nivel):
        self.nombre = nombre
        self.nivel = nivel
    
    def mostrar_datos(self):
        print(f"Nombre: {self.nombre}")
        print(f"Nivel: {self.nivel}")

class Guerrero(Personaje):
    def pelear():
        print("Soy {self.nombre} y voy a pelear en el Nivel {self.nivel}")

class Mago(Personaje):
    def pelear():
        print("Soy {self.nombre} y tengo poderes en el Nivel {self.nivel}")

guerrero1 = Guerrero("Manchester", "1")
guerrero1.mostrar_datos()

mago1 = Mago("Negro", "2")
mago1.mostrar_datos()

print(mago1.nombre)
print(guerrero1.nombre)

# %%
# Challenge 4 🤺 - 20 min
# Crear dos personajes de una historia que se representen a traves de clases. Ejemplo: Un hereo y un villano.
# Cada personaje debe tener poderes o acciones diferentes. Y deben presentarse en una frase.

# Ejemplo: Yo me llamo pepito y tengo super fuerza
# Ejemplo: Yo me llamo juanito y puedo volar

class Personajes:

      def __init__(self, nombre, poder):
    
            self.nombre = nombre
            self.poder = poder

class Villanos(Personajes):
      
      def presentacion(self):
            print("Soy {nombre} y mi poder es {poder}")

class Heroes(Personajes):
      
      def presentacion(self):
            print("Soy {nombre} y mi poder es {poder}")

villano1 = Villanos("Lordbad", "volar")
heroes1 = Heroes("LoordGood", "correr")

print(villano1.presentacion())
print(heroes1.presentacion())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 28
#      25 villano1 = Villanos("Lordbad", "volar")
#      26 heroes1 = Heroes("LoordGood", "correr")
# ---> 28 print(villano1.presentacion())
#      29 print(heroes1.presentacion())
#
# TypeError: Villanos.presentacion() takes 0 positional arguments but 1 was given
