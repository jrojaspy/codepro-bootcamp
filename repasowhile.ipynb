# %%
# Mostrar los numeros del 1 al 5, uno por uno.

contador = 0

while contador < 5:
    contador = contador + 1
    print(f"* Número {contador} *")
# Out:
# * Número 1 *
# * Número 2 *
# * Número 3 *
# * Número 4 *
# * Número 5 *
